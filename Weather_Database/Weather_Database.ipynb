# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Pack the latitudes and longitueds as pairs by zipping them.
lat_lngs = zip(lats, lngs)

# Returns a zip object in memory.
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the citipy script from the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination:

# Iterate through the coordinates' zipped tuple.
for coordinate in coordinates:
    # Get the name of the city nearest to the coordinates and save it in the "city" variable.
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 719

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library.
import time

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list. Reference the index and the city in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    # Check if the remainder of the index divided by 50 is equal to 0 and if the index >= 50    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city. 
    # Remove the blank spaces in the city name and concatenate it with '+'.
    # This will find the corresponding weather data for the city instead of finding 
    # the weather data for the first part of the city name.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record count, set count, and the city that is being processed.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count before the next city is processed.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON file and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        # pass is a general purpose statement to handle all errors encountered
        # and to alloow the program to continue
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mangan
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | sitka
# Processing Record 5 of Set 1 | ketchikan
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | sujiatun
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | saint-pierre
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | tasiilaq
# Processing Record 15 of Set 1 | ilulissat
# Processing Record 16 of Set 1 | port lincoln
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | sao filipe
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | muisne
# Processing Record 22 of Set 1 | maceio
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | muroto
# Processing Record 26 of Set 1 | uglovskoye
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 1 | college
# Processing Record 30 of Set 1 | huarmey
# Processing Record 31 of Set 1 | codrington
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | saint george
# Processing Record 34 of Set 1 | puerto colombia
# Processing Record 35 of Set 1 | filadelfia
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | aklavik
# Processing Record 38 of Set 1 | nabire
# Processing Record 39 of Set 1 | nishihara
# Processing Record 40 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | kamenka
# Processing Record 44 of Set 1 | makakilo city
# Processing Record 45 of Set 1 | zalantun
# Processing Record 46 of Set 1 | roebourne
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | ordzhonikidze
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | weymouth
# Processing Record 5 of Set 2 | vilhena
# Processing Record 6 of Set 2 | kyritz
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | ondjiva
# Processing Record 10 of Set 2 | mahebourg
# Processing Record 11 of Set 2 | arlit
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | ponazyrevo
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | salalah
# Processing Record 16 of Set 2 | elizabeth city
# Processing Record 17 of Set 2 | pascagoula
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | ballina
# Processing Record 20 of Set 2 | saldanha
# Processing Record 21 of Set 2 | klaksvik
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | benque viejo
# City not found. Skipping...
# Processing Record 24 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 2 | nanortalik
# Processing Record 26 of Set 2 | alofi
# Processing Record 27 of Set 2 | talnakh
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | tura
# Processing Record 30 of Set 2 | borzya
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | okhotsk
# Processing Record 33 of Set 2 | san patricio
# Processing Record 34 of Set 2 | airai
# Processing Record 35 of Set 2 | severo-yeniseyskiy
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | cayenne
# Processing Record 38 of Set 2 | aksum
# Processing Record 39 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | muzhi
# Processing Record 42 of Set 2 | port hardy
# Processing Record 43 of Set 2 | vilyuysk
# Processing Record 44 of Set 2 | la ronge
# Processing Record 45 of Set 2 | pevek
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | guajara-mirim
# City not found. Skipping...
# Processing Record 48 of Set 2 | sorong
# Processing Record 49 of Set 2 | bonthe
# Processing Record 50 of Set 2 | beloha
# Processing Record 1 of Set 3 | minas
# Processing Record 2 of Set 3 | santa rosa
# Processing Record 3 of Set 3 | aykhal
# Processing Record 4 of Set 3 | diffa
# Processing Record 5 of Set 3 | esmeraldas
# Processing Record 6 of Set 3 | adrar
# Processing Record 7 of Set 3 | karatau
# Processing Record 8 of Set 3 | banjar
# Processing Record 9 of Set 3 | westport
# Processing Record 10 of Set 3 | danshui
# Processing Record 11 of Set 3 | nouadhibou
# Processing Record 12 of Set 3 | lewiston
# Processing Record 13 of Set 3 | saskylakh
# Processing Record 14 of Set 3 | luderitz
# Processing Record 15 of Set 3 | cabrobo
# Processing Record 16 of Set 3 | kirakira
# Processing Record 17 of Set 3 | bubaque
# Processing Record 18 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 3 | viedma
# Processing Record 20 of Set 3 | kedrovyy
# Processing Record 21 of Set 3 | katherine
# Processing Record 22 of Set 3 | rawson
# Processing Record 23 of Set 3 | atka
# City not found. Skipping...
# Processing Record 24 of Set 3 | hobart
# Processing Record 25 of Set 3 | goderich
# Processing Record 26 of Set 3 | lorengau
# Processing Record 27 of Set 3 | samarai
# Processing Record 28 of Set 3 | touros
# Processing Record 29 of Set 3 | carnarvon
# Processing Record 30 of Set 3 | labuan
# Processing Record 31 of Set 3 | cahors
# Processing Record 32 of Set 3 | pacific grove
# Processing Record 33 of Set 3 | constantine
# Processing Record 34 of Set 3 | lompoc
# Processing Record 35 of Set 3 | sokolo
# Processing Record 36 of Set 3 | port elizabeth
# Processing Record 37 of Set 3 | broome
# Processing Record 38 of Set 3 | ahipara
# Processing Record 39 of Set 3 | kahului
# Processing Record 40 of Set 3 | pochutla
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | faanui
# Processing Record 43 of Set 3 | hasaki
# Processing Record 44 of Set 3 | shambu
# Processing Record 45 of Set 3 | natal
# Processing Record 46 of Set 3 | torbay
# Processing Record 47 of Set 3 | port alfred
# Processing Record 48 of Set 3 | letnyaya stavka
# Processing Record 49 of Set 3 | varhaug
# Processing Record 50 of Set 3 | geraldton
# Processing Record 1 of Set 4 | vila velha
# Processing Record 2 of Set 4 | cape town
# Processing Record 3 of Set 4 | ribeira brava
# Processing Record 4 of Set 4 | cape canaveral
# Processing Record 5 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 4 | dalhousie
# Processing Record 7 of Set 4 | junin
# Processing Record 8 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 4 | sayansk
# Processing Record 10 of Set 4 | allanridge
# Processing Record 11 of Set 4 | jalu
# Processing Record 12 of Set 4 | bandarbeyla
# Processing Record 13 of Set 4 | eureka
# Processing Record 14 of Set 4 | arraial do cabo
# Processing Record 15 of Set 4 | luganville
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | yeniseysk
# Processing Record 19 of Set 4 | bardsir
# Processing Record 20 of Set 4 | vaini
# Processing Record 21 of Set 4 | barcelos
# Processing Record 22 of Set 4 | kalaleh
# Processing Record 23 of Set 4 | erzin
# Processing Record 24 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 4 | avera
# Processing Record 26 of Set 4 | seymchan
# Processing Record 27 of Set 4 | beringovskiy
# Processing Record 28 of Set 4 | khandyga
# Processing Record 29 of Set 4 | coxim
# Processing Record 30 of Set 4 | khatanga
# Processing Record 31 of Set 4 | olga
# Processing Record 32 of Set 4 | katsuura
# Processing Record 33 of Set 4 | paragominas
# Processing Record 34 of Set 4 | kruisfontein
# Processing Record 35 of Set 4 | walvis bay
# Processing Record 36 of Set 4 | hualmay
# Processing Record 37 of Set 4 | hofn
# Processing Record 38 of Set 4 | boende
# Processing Record 39 of Set 4 | narsaq
# Processing Record 40 of Set 4 | baiao
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | naples
# Processing Record 43 of Set 4 | ahuimanu
# Processing Record 44 of Set 4 | general roca
# Processing Record 45 of Set 4 | inuvik
# Processing Record 46 of Set 4 | victoria
# Processing Record 47 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 4 | prestea
# Processing Record 49 of Set 4 | leningradskiy
# Processing Record 50 of Set 4 | los llanos de aridane
# Processing Record 1 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 2 of Set 5 | souillac
# Processing Record 3 of Set 5 | kieta
# Processing Record 4 of Set 5 | altamont
# Processing Record 5 of Set 5 | santa cruz
# Processing Record 6 of Set 5 | coquimbo
# Processing Record 7 of Set 5 | dunedin
# Processing Record 8 of Set 5 | batetskiy
# Processing Record 9 of Set 5 | gat
# Processing Record 10 of Set 5 | yamada
# Processing Record 11 of Set 5 | volchansk
# Processing Record 12 of Set 5 | chokurdakh
# Processing Record 13 of Set 5 | andrews
# Processing Record 14 of Set 5 | grand gaube
# Processing Record 15 of Set 5 | itapaci
# Processing Record 16 of Set 5 | severo-kurilsk
# Processing Record 17 of Set 5 | kiama
# Processing Record 18 of Set 5 | tiksi
# Processing Record 19 of Set 5 | aripuana
# Processing Record 20 of Set 5 | rebrikha
# Processing Record 21 of Set 5 | derzhavinsk
# Processing Record 22 of Set 5 | safaga
# Processing Record 23 of Set 5 | sur
# Processing Record 24 of Set 5 | sambava
# Processing Record 25 of Set 5 | atambua
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | clyde river
# Processing Record 28 of Set 5 | erenhot
# Processing Record 29 of Set 5 | margate
# Processing Record 30 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 31 of Set 5 | tilichiki
# Processing Record 32 of Set 5 | antalaha
# Processing Record 33 of Set 5 | semnan
# Processing Record 34 of Set 5 | porto recanati
# Processing Record 35 of Set 5 | tuatapere
# Processing Record 36 of Set 5 | komsomolskiy
# Processing Record 37 of Set 5 | broken hill
# Processing Record 38 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 5 | hambantota
# Processing Record 40 of Set 5 | rio grande
# Processing Record 41 of Set 5 | ust-kut
# Processing Record 42 of Set 5 | ekhabi
# Processing Record 43 of Set 5 | urumqi
# Processing Record 44 of Set 5 | plavinas
# Processing Record 45 of Set 5 | sept-iles
# Processing Record 46 of Set 5 | lindlar
# Processing Record 47 of Set 5 | port-gentil
# Processing Record 48 of Set 5 | aksu
# Processing Record 49 of Set 5 | kangaatsiaq
# Processing Record 50 of Set 5 | guiratinga
# Processing Record 1 of Set 6 | upernavik
# Processing Record 2 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 6 | bodden town
# Processing Record 4 of Set 6 | lavrentiya
# Processing Record 5 of Set 6 | bethel
# Processing Record 6 of Set 6 | hami
# Processing Record 7 of Set 6 | pangai
# Processing Record 8 of Set 6 | port blair
# Processing Record 9 of Set 6 | bambanglipuro
# Processing Record 10 of Set 6 | les cayes
# Processing Record 11 of Set 6 | ternate
# Processing Record 12 of Set 6 | alugan
# Processing Record 13 of Set 6 | alice springs
# Processing Record 14 of Set 6 | asuncion
# Processing Record 15 of Set 6 | poum
# Processing Record 16 of Set 6 | georgetown
# Processing Record 17 of Set 6 | haines junction
# Processing Record 18 of Set 6 | carballo
# Processing Record 19 of Set 6 | qasigiannguit
# Processing Record 20 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 6 | lima
# Processing Record 22 of Set 6 | xining
# Processing Record 23 of Set 6 | christchurch
# Processing Record 24 of Set 6 | provideniya
# Processing Record 25 of Set 6 | bilma
# Processing Record 26 of Set 6 | jingdezhen
# Processing Record 27 of Set 6 | mezen
# Processing Record 28 of Set 6 | north bay
# Processing Record 29 of Set 6 | egvekinot
# Processing Record 30 of Set 6 | sao felix do xingu
# Processing Record 31 of Set 6 | limbang
# Processing Record 32 of Set 6 | rio gallegos
# Processing Record 33 of Set 6 | korla
# Processing Record 34 of Set 6 | willowmore
# Processing Record 35 of Set 6 | lagoa
# Processing Record 36 of Set 6 | kapoeta
# Processing Record 37 of Set 6 | keetmanshoop
# Processing Record 38 of Set 6 | lodja
# Processing Record 39 of Set 6 | tokat
# Processing Record 40 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 41 of Set 6 | new amsterdam
# Processing Record 42 of Set 6 | jaguarao
# Processing Record 43 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 6 | grindavik
# Processing Record 45 of Set 6 | male
# Processing Record 46 of Set 6 | acajutla
# Processing Record 47 of Set 6 | zaysan
# Processing Record 48 of Set 6 | emirdag
# Processing Record 49 of Set 6 | qaqortoq
# Processing Record 50 of Set 6 | obihiro
# Processing Record 1 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 7 | shuyskoye
# Processing Record 3 of Set 7 | bambous virieux
# Processing Record 4 of Set 7 | portland
# Processing Record 5 of Set 7 | nemuro
# Processing Record 6 of Set 7 | faridpur
# Processing Record 7 of Set 7 | te anau
# Processing Record 8 of Set 7 | ulladulla
# Processing Record 9 of Set 7 | san quintin
# Processing Record 10 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 7 | camacha
# Processing Record 12 of Set 7 | launceston
# Processing Record 13 of Set 7 | east london
# Processing Record 14 of Set 7 | kathu
# Processing Record 15 of Set 7 | mayo
# Processing Record 16 of Set 7 | tevaitoa
# Processing Record 17 of Set 7 | tahlequah
# Processing Record 18 of Set 7 | marzuq
# Processing Record 19 of Set 7 | tateyama
# Processing Record 20 of Set 7 | palu
# Processing Record 21 of Set 7 | patan
# Processing Record 22 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 7 | coihaique
# Processing Record 24 of Set 7 | dodge city
# Processing Record 25 of Set 7 | tucumcari
# Processing Record 26 of Set 7 | leshukonskoye
# Processing Record 27 of Set 7 | daru
# Processing Record 28 of Set 7 | mantua
# Processing Record 29 of Set 7 | guaymas
# Processing Record 30 of Set 7 | flin flon
# Processing Record 31 of Set 7 | guerrero negro
# Processing Record 32 of Set 7 | kavieng
# Processing Record 33 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 7 | itarema
# Processing Record 35 of Set 7 | longyearbyen
# Processing Record 36 of Set 7 | atar
# Processing Record 37 of Set 7 | tiznit
# Processing Record 38 of Set 7 | san angelo
# Processing Record 39 of Set 7 | saint-leu
# Processing Record 40 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 41 of Set 7 | cidreira
# Processing Record 42 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 7 | huancavelica
# Processing Record 44 of Set 7 | karratha
# Processing Record 45 of Set 7 | husavik
# Processing Record 46 of Set 7 | am timan
# Processing Record 47 of Set 7 | shingu
# Processing Record 48 of Set 7 | acheng
# Processing Record 49 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 7 | umm kaddadah
# Processing Record 1 of Set 8 | hagere selam
# Processing Record 2 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 8 | dingle
# Processing Record 4 of Set 8 | tucurui
# Processing Record 5 of Set 8 | charcas
# Processing Record 6 of Set 8 | nantucket
# Processing Record 7 of Set 8 | barra patuca
# Processing Record 8 of Set 8 | puerto leguizamo
# Processing Record 9 of Set 8 | piracanjuba
# Processing Record 10 of Set 8 | vestmannaeyjar
# Processing Record 11 of Set 8 | barrosas
# Processing Record 12 of Set 8 | aitape
# Processing Record 13 of Set 8 | saint anthony
# Processing Record 14 of Set 8 | salinopolis
# Processing Record 15 of Set 8 | aswan
# Processing Record 16 of Set 8 | nieuw amsterdam
# Processing Record 17 of Set 8 | nhulunbuy
# Processing Record 18 of Set 8 | vostok
# Processing Record 19 of Set 8 | illescas
# Processing Record 20 of Set 8 | eenhana
# Processing Record 21 of Set 8 | almaznyy
# Processing Record 22 of Set 8 | dhidhdhoo
# Processing Record 23 of Set 8 | bazarnyy karabulak
# Processing Record 24 of Set 8 | norman wells
# Processing Record 25 of Set 8 | managua
# Processing Record 26 of Set 8 | garden city
# Processing Record 27 of Set 8 | caravelas
# Processing Record 28 of Set 8 | pundaguitan
# Processing Record 29 of Set 8 | omsukchan
# Processing Record 30 of Set 8 | baft
# Processing Record 31 of Set 8 | kozulka
# Processing Record 32 of Set 8 | north bend
# Processing Record 33 of Set 8 | cavalcante
# Processing Record 34 of Set 8 | wuwei
# Processing Record 35 of Set 8 | ancud
# Processing Record 36 of Set 8 | vanavara
# Processing Record 37 of Set 8 | nola
# Processing Record 38 of Set 8 | kotelnikovo
# Processing Record 39 of Set 8 | khor
# Processing Record 40 of Set 8 | port macquarie
# Processing Record 41 of Set 8 | acapulco
# Processing Record 42 of Set 8 | ust-omchug
# Processing Record 43 of Set 8 | bud
# Processing Record 44 of Set 8 | shrewsbury
# Processing Record 45 of Set 8 | iwanai
# Processing Record 46 of Set 8 | bontang
# Processing Record 47 of Set 8 | coos bay
# Processing Record 48 of Set 8 | tsabong
# Processing Record 49 of Set 8 | hokitika
# Processing Record 50 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 9 | tigil
# Processing Record 2 of Set 9 | peace river
# Processing Record 3 of Set 9 | sechura
# Processing Record 4 of Set 9 | nicoya
# Processing Record 5 of Set 9 | whitehorse
# Processing Record 6 of Set 9 | conkal
# Processing Record 7 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 8 of Set 9 | wellington
# Processing Record 9 of Set 9 | lasa
# Processing Record 10 of Set 9 | tezu
# Processing Record 11 of Set 9 | the valley
# Processing Record 12 of Set 9 | siruguppa
# Processing Record 13 of Set 9 | fortuna
# Processing Record 14 of Set 9 | lokosovo
# Processing Record 15 of Set 9 | banyo
# Processing Record 16 of Set 9 | belaya gora
# Processing Record 17 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 9 | soyo
# Processing Record 19 of Set 9 | luanda
# Processing Record 20 of Set 9 | batagay-alyta
# Processing Record 21 of Set 9 | santa maria
# Processing Record 22 of Set 9 | macas
# Processing Record 23 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 9 | yurgamysh
# Processing Record 25 of Set 9 | ngunguru
# Processing Record 26 of Set 9 | weyburn
# Processing Record 27 of Set 9 | bowen
# Processing Record 28 of Set 9 | saposoa
# Processing Record 29 of Set 9 | nanning
# Processing Record 30 of Set 9 | half moon bay
# Processing Record 31 of Set 9 | mehamn
# Processing Record 32 of Set 9 | zhigansk
# Processing Record 33 of Set 9 | lisala
# Processing Record 34 of Set 9 | lleida
# Processing Record 35 of Set 9 | malartic
# Processing Record 36 of Set 9 | srednekolymsk
# Processing Record 37 of Set 9 | berlevag
# Processing Record 38 of Set 9 | pisco
# Processing Record 39 of Set 9 | mecca
# Processing Record 40 of Set 9 | constitucion
# Processing Record 41 of Set 9 | los lunas
# Processing Record 42 of Set 9 | henties bay
# Processing Record 43 of Set 9 | bilibino
# Processing Record 44 of Set 9 | esperance
# Processing Record 45 of Set 9 | skjervoy
# Processing Record 46 of Set 9 | mulege
# Processing Record 47 of Set 9 | aanekoski
# Processing Record 48 of Set 9 | pastos bons
# Processing Record 49 of Set 9 | xuddur
# Processing Record 50 of Set 9 | rio cuarto
# Processing Record 1 of Set 10 | monrovia
# Processing Record 2 of Set 10 | bashtanka
# Processing Record 3 of Set 10 | port pirie
# Processing Record 4 of Set 10 | lichinga
# Processing Record 5 of Set 10 | magaria
# Processing Record 6 of Set 10 | pemangkat
# Processing Record 7 of Set 10 | de-kastri
# Processing Record 8 of Set 10 | torbat-e jam
# Processing Record 9 of Set 10 | deer lake
# Processing Record 10 of Set 10 | harlingen
# Processing Record 11 of Set 10 | bourail
# Processing Record 12 of Set 10 | karla
# Processing Record 13 of Set 10 | port-cartier
# Processing Record 14 of Set 10 | coalinga
# Processing Record 15 of Set 10 | panzhihua
# Processing Record 16 of Set 10 | reinosa
# Processing Record 17 of Set 10 | faya
# Processing Record 18 of Set 10 | gizo
# Processing Record 19 of Set 10 | sinnamary
# Processing Record 20 of Set 10 | kutum
# Processing Record 21 of Set 10 | iquique
# Processing Record 22 of Set 10 | flinders
# Processing Record 23 of Set 10 | kurumkan
# Processing Record 24 of Set 10 | itaueira
# Processing Record 25 of Set 10 | inhambane
# Processing Record 26 of Set 10 | boa vista
# Processing Record 27 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 28 of Set 10 | stryn
# Processing Record 29 of Set 10 | kovdor
# Processing Record 30 of Set 10 | qui nhon
# Processing Record 31 of Set 10 | yakeshi
# Processing Record 32 of Set 10 | jining
# Processing Record 33 of Set 10 | saint-augustin
# Processing Record 34 of Set 10 | lake havasu city
# Processing Record 35 of Set 10 | lincoln
# Processing Record 36 of Set 10 | san policarpo
# Processing Record 37 of Set 10 | namibe
# Processing Record 38 of Set 10 | imeni poliny osipenko
# Processing Record 39 of Set 10 | new port richey
# Processing Record 40 of Set 10 | summerside
# Processing Record 41 of Set 10 | chuy
# Processing Record 42 of Set 10 | yar-sale
# Processing Record 43 of Set 10 | praia da vitoria
# Processing Record 44 of Set 10 | mazabuka
# Processing Record 45 of Set 10 | taunggyi
# Processing Record 46 of Set 10 | fairbanks
# Processing Record 47 of Set 10 | zhanaozen
# Processing Record 48 of Set 10 | churapcha
# Processing Record 49 of Set 10 | naberera
# Processing Record 50 of Set 10 | songea
# Processing Record 1 of Set 11 | ihosy
# Processing Record 2 of Set 11 | deputatskiy
# Processing Record 3 of Set 11 | okha
# Processing Record 4 of Set 11 | sainte-maxime
# Processing Record 5 of Set 11 | tottori
# Processing Record 6 of Set 11 | sabha
# Processing Record 7 of Set 11 | tupik
# Processing Record 8 of Set 11 | mattru
# Processing Record 9 of Set 11 | koppies
# Processing Record 10 of Set 11 | evensk
# Processing Record 11 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 11 | pinawa
# Processing Record 13 of Set 11 | hammerfest
# Processing Record 14 of Set 11 | chimbote
# Processing Record 15 of Set 11 | noyabrsk
# Processing Record 16 of Set 11 | zaltan
# Processing Record 17 of Set 11 | bethanien
# Processing Record 18 of Set 11 | kargasok
# Processing Record 19 of Set 11 | steinbach
# Processing Record 20 of Set 11 | nizwa
# Processing Record 21 of Set 11 | saint-francois
# Processing Record 22 of Set 11 | goulburn
# Processing Record 23 of Set 11 | yarada
# Processing Record 24 of Set 11 | mackay
# Processing Record 25 of Set 11 | linxia
# Processing Record 26 of Set 11 | marang
# Processing Record 27 of Set 11 | algiers
# Processing Record 28 of Set 11 | hartselle
# Processing Record 29 of Set 11 | byron bay
# Processing Record 30 of Set 11 | solnechnyy
# Processing Record 31 of Set 11 | bulgan
# Processing Record 32 of Set 11 | rapid valley
# Processing Record 33 of Set 11 | mount gambier
# Processing Record 34 of Set 11 | obo
# Processing Record 35 of Set 11 | kualakapuas
# Processing Record 36 of Set 11 | kailua
# Processing Record 37 of Set 11 | warwick
# Processing Record 38 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 39 of Set 11 | dalvik
# Processing Record 40 of Set 11 | necochea
# Processing Record 41 of Set 11 | huancabamba
# Processing Record 42 of Set 11 | vao
# Processing Record 43 of Set 11 | karaton
# Processing Record 44 of Set 11 | laukaa
# Processing Record 45 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 11 | ocampo
# Processing Record 47 of Set 11 | puerto madryn
# Processing Record 48 of Set 11 | macae
# Processing Record 49 of Set 11 | dawson creek
# Processing Record 50 of Set 11 | anadyr
# Processing Record 1 of Set 12 | krasnoselkup
# Processing Record 2 of Set 12 | charleston
# Processing Record 3 of Set 12 | beisfjord
# Processing Record 4 of Set 12 | kribi
# Processing Record 5 of Set 12 | kodinsk
# Processing Record 6 of Set 12 | yumen
# Processing Record 7 of Set 12 | sakakah
# Processing Record 8 of Set 12 | mpwapwa
# Processing Record 9 of Set 12 | umm lajj
# Processing Record 10 of Set 12 | manica
# Processing Record 11 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 12 | port hedland
# Processing Record 13 of Set 12 | mareeba
# Processing Record 14 of Set 12 | cockburn town
# Processing Record 15 of Set 12 | upington
# Processing Record 16 of Set 12 | timmins
# Processing Record 17 of Set 12 | udarnyy
# Processing Record 18 of Set 12 | shar
# Processing Record 19 of Set 12 | montepuez
# Processing Record 20 of Set 12 | san luis
# Processing Record 21 of Set 12 | camana
# Processing Record 22 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 12 | rivne
# Processing Record 24 of Set 12 | killybegs
# Processing Record 25 of Set 12 | bonavista
# Processing Record 26 of Set 12 | synya
# Processing Record 27 of Set 12 | magrath
# Processing Record 28 of Set 12 | bathsheba
# Processing Record 29 of Set 12 | harda
# Processing Record 30 of Set 12 | isangel
# Processing Record 31 of Set 12 | olafsvik
# Processing Record 32 of Set 12 | wattegama
# Processing Record 33 of Set 12 | hamilton
# Processing Record 34 of Set 12 | vysotsk
# Processing Record 35 of Set 12 | tessalit
# Processing Record 36 of Set 12 | plaisir
# Processing Record 37 of Set 12 | ashland
# Processing Record 38 of Set 12 | takoradi
# Processing Record 39 of Set 12 | shahrud
# Processing Record 40 of Set 12 | beyneu
# Processing Record 41 of Set 12 | trincomalee
# Processing Record 42 of Set 12 | japura
# Processing Record 43 of Set 12 | verkhnyaya inta
# Processing Record 44 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 45 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 12 | mangai
# Processing Record 48 of Set 12 | whakatane
# Processing Record 49 of Set 12 | nyurba
# Processing Record 50 of Set 12 | ipeti
# City not found. Skipping...
# Processing Record 1 of Set 13 | aviles
# Processing Record 2 of Set 13 | iqaluit
# Processing Record 3 of Set 13 | taoudenni
# Processing Record 4 of Set 13 | hervey bay
# Processing Record 5 of Set 13 | macau
# Processing Record 6 of Set 13 | rocha
# Processing Record 7 of Set 13 | mindelo
# Processing Record 8 of Set 13 | maniitsoq
# Processing Record 9 of Set 13 | bandrele
# Processing Record 10 of Set 13 | ostrovnoy
# Processing Record 11 of Set 13 | farafangana
# Processing Record 12 of Set 13 | cabedelo
# Processing Record 13 of Set 13 | emsdetten
# Processing Record 14 of Set 13 | mlonggo
# Processing Record 15 of Set 13 | kabare
# Processing Record 16 of Set 13 | vila nova de milfontes
# Processing Record 17 of Set 13 | lamesa
# Processing Record 18 of Set 13 | atbasar
# Processing Record 19 of Set 13 | odweyne
# Processing Record 20 of Set 13 | siddapur
# Processing Record 21 of Set 13 | claudio
# Processing Record 22 of Set 13 | pavino
# Processing Record 23 of Set 13 | vardo
# Processing Record 24 of Set 13 | kirovskiy
# Processing Record 25 of Set 13 | burnie
# Processing Record 26 of Set 13 | tazovskiy
# Processing Record 27 of Set 13 | chopan
# Processing Record 28 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 13 | kapit
# Processing Record 30 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 13 | helong
# Processing Record 32 of Set 13 | aasiaat
# Processing Record 33 of Set 13 | goma
# Processing Record 34 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 35 of Set 13 | yhu
# Processing Record 36 of Set 13 | meulaboh
# Processing Record 37 of Set 13 | garbolovo
# Processing Record 38 of Set 13 | pangnirtung
# Processing Record 39 of Set 13 | sioux lookout
# Processing Record 40 of Set 13 | quatre cocos
# Processing Record 41 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 42 of Set 13 | tahe
# Processing Record 43 of Set 13 | floro
# Processing Record 44 of Set 13 | belgrade
# Processing Record 45 of Set 13 | gimli
# Processing Record 46 of Set 13 | sao joao da barra
# Processing Record 47 of Set 13 | buala
# Processing Record 48 of Set 13 | kununurra
# Processing Record 49 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 13 | kuala kedah
# Processing Record 1 of Set 14 | lingyuan
# Processing Record 2 of Set 14 | novo aripuana
# Processing Record 3 of Set 14 | san jeronimo
# Processing Record 4 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 5 of Set 14 | maicao
# Processing Record 6 of Set 14 | zyryanka
# Processing Record 7 of Set 14 | tuy hoa
# Processing Record 8 of Set 14 | manaure
# Processing Record 9 of Set 14 | biltine
# Processing Record 10 of Set 14 | el alto
# Processing Record 11 of Set 14 | wanning
# Processing Record 12 of Set 14 | mankono
# Processing Record 13 of Set 14 | brunsbuttel
# Processing Record 14 of Set 14 | acarau
# Processing Record 15 of Set 14 | sarkand
# Processing Record 16 of Set 14 | tahta
# Processing Record 17 of Set 14 | namatanai
# Processing Record 18 of Set 14 | santa isabel
# Processing Record 19 of Set 14 | utete
# Processing Record 20 of Set 14 | plover
# Processing Record 21 of Set 14 | durban
# Processing Record 22 of Set 14 | maridi
# Processing Record 23 of Set 14 | huilong
# Processing Record 24 of Set 14 | belen
# Processing Record 25 of Set 14 | sembe
# Processing Record 26 of Set 14 | huaiyuan
# Processing Record 27 of Set 14 | rundu
# Processing Record 28 of Set 14 | paragould
# Processing Record 29 of Set 14 | san miguel
# Processing Record 30 of Set 14 | nador
# Processing Record 31 of Set 14 | copacabana
# Processing Record 32 of Set 14 | san vicente
# Processing Record 33 of Set 14 | gejiu
# Processing Record 34 of Set 14 | teguise
# Processing Record 35 of Set 14 | tromso
# Processing Record 36 of Set 14 | mount pleasant
# Processing Record 37 of Set 14 | danilov
# Processing Record 38 of Set 14 | padang
# Processing Record 39 of Set 14 | treinta y tres
# Processing Record 40 of Set 14 | jambalo
# Processing Record 41 of Set 14 | grimari
# City not found. Skipping...
# Processing Record 42 of Set 14 | skelleftea
# Processing Record 43 of Set 14 | lircay
# Processing Record 44 of Set 14 | shizilu
# Processing Record 45 of Set 14 | shorapur
# Processing Record 46 of Set 14 | warmbad
# Processing Record 47 of Set 14 | makaha
# Processing Record 48 of Set 14 | moss vale
# Processing Record 49 of Set 14 | gorin
# Processing Record 50 of Set 14 | lukovetskiy
# Processing Record 1 of Set 15 | chipinge
# Processing Record 2 of Set 15 | tres arroyos
# Processing Record 3 of Set 15 | sandviken
# Processing Record 4 of Set 15 | joquicingo
# Processing Record 5 of Set 15 | colombo
# Processing Record 6 of Set 15 | homer
# Processing Record 7 of Set 15 | sibolga
# Processing Record 8 of Set 15 | weligama
# Processing Record 9 of Set 15 | awjilah
# Processing Record 10 of Set 15 | moshi
# Processing Record 11 of Set 15 | seoul
# Processing Record 12 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 15 | carlisle
# Processing Record 14 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 15 | uddiawan
# Processing Record 16 of Set 15 | asosa
# Processing Record 17 of Set 15 | wajima
# Processing Record 18 of Set 15 | araouane
# Processing Record 19 of Set 15 | ust-nera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 664

# %%
# Convert the array of dictionaries in city_data to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mangan      IN  27.5167   88.5333     69.57        38           3
# 1      Hermanus      ZA -34.4187   19.2345     65.10        87          97
# 2       Qaanaaq      GL  77.4840  -69.3632     -2.72        97          99
# 3         Sitka      US  57.0531 -135.3300     34.52        98         100
# 4     Ketchikan      US  55.3422 -131.6461     46.87        93          90
# 5      Sujiatun      CN  41.6592  123.3392     48.38        61          20
# 6       Ushuaia      AR -54.8000  -68.3000     46.06        71          75
# 7   New Norfolk      AU -42.7826  147.0587     65.70        35           1
# 8   Tuktoyaktuk      CA  69.4541 -133.0374     -9.40        77          90
# 9  Saint-Pierre      RE -21.3393   55.4781     80.24        83          75
#
#    Wind Speed Current Description
# 0        5.46           clear sky
# 1       15.37     overcast clouds
# 2        2.42     overcast clouds
# 3        2.75          light rain
# 4       13.80       moderate rain
# 5       13.42          few clouds
# 6       13.80       moderate rain
# 7        3.38           clear sky
# 8       20.71          light snow
# 9        8.05          light rain

# %%
# Create the output file (CSV). Save the file to the Weather_Database folder with the 
# file name "WeatherPy_Database.csv".
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data_df into a CSV with the index label (or column A) header as "City_ID".
city_data_df.to_csv(output_data_file, index_label="City_ID")
